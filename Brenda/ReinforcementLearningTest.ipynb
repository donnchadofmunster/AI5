# %%
import gym
from gym import spaces
import numpy as np

class LineFollowingEnv(gym.Env):
    def __init__(self, C1=1.0, C2=1.0):
        super(LineFollowingEnv, self).__init__()

        # Define action and observation space
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(1,), dtype=np.float32)  # angular velocity
        self.observation_space = spaces.Box(low=np.array([-1.0, -180.0]), high=np.array([1.0, 180.0]), dtype=np.float32)  # [d, theta]
        
        self.C1 = C1
        self.C2 = C2
        self.dt = 0.05
        self.forward_speed = 0.3
        self.max_steps = 1000
        self.current_step = 0

    def reset(self):
        # Randomly initialize distance and angle
        self.d = np.random.uniform(-1, 1)      # Normalized distance
        self.theta = np.random.uniform(-180, 180)  # Angle in degrees
        
        self.current_step = 0
        return np.array([self.d, self.theta], dtype=np.float32)

    def step(self, action):
        self.current_step += 1
        
        # Apply the action (update theta based on the steering angle)
        angular_velocity = action[0]
        delta_theta = angular_velocity * self.dt
        self.theta += np.degrees(delta_theta)
        
        # Simulate the effect on the line position
        self.d += np.sin(np.radians(self.theta)) * 0.05  # Change 0.05 to tune motion sensitivity

        # Calculate reward
        reward = -1 * (self.C1 * (self.d ** 2) + self.C2 * (self.theta ** 2))

        # Check if the episode is done
        done = bool(
            abs(self.d) < 0.05 or self.current_step >= self.max_steps  # Out of bounds or max steps reached
        )

        # Return step information
        obs = np.array([self.d, self.theta], dtype=np.float32)
        return obs, reward, done, {}

    def render(self, mode='console'):
        print(f"Step: {self.current_step}, d: {self.d}, theta: {self.theta}")

# %%
from stable_baselines3 import PPO

# Create environment
env = LineFollowingEnv(C1=1.0, C2=0.01)

# Initialize the model
model = PPO("MlpPolicy", env, verbose=1)

# Train the model
model.learn(total_timesteps=100000)

# Save the model
model.save("ppo_line_follower")
# Out:
# C:\Users\brend\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# C:\Users\brend\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 673      |
# |    ep_rew_mean     | -3.6e+05 |
# | time/              |          |
# |    fps             | 1511     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 357           |
# |    ep_rew_mean          | -1.48e+05     |
# | time/                   |               |
# |    fps                  | 866           |
# |    iterations           | 2             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 5.8278645e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -4.54e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.24e+07      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000158     |
# |    std                  | 1             |
# |    value_loss           | 1.17e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 425          |
# |    ep_rew_mean          | -1.69e+05    |
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0010083301 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00133     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+07     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000665    |
# |    std                  | 1            |
# |    value_loss           | 3.93e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 381          |
# |    ep_rew_mean          | -1.71e+05    |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 4            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0010928118 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00135     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95e+07     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000544    |
# |    std                  | 0.999        |
# |    value_loss           | 6.78e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 405           |
# |    ep_rew_mean          | -1.82e+05     |
# | time/                   |               |
# |    fps                  | 698           |
# |    iterations           | 5             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 3.1984237e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.000162     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.04e+07      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -7.51e-06     |
# |    std                  | 0.999         |
# |    value_loss           | 1.48e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 452          |
# |    ep_rew_mean          | -1.87e+05    |
# | time/                   |              |
# |    fps                  | 682          |
# |    iterations           | 6            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0032094156 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00274      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.49e+07     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00218     |
# |    std                  | 0.999        |
# |    value_loss           | 7.48e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 448          |
# |    ep_rew_mean          | -1.88e+05    |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 7            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0013370619 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00244     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3e+06      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00106     |
# |    std                  | 0.999        |
# |    value_loss           | 6.55e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 396           |
# |    ep_rew_mean          | -1.56e+05     |
# | time/                   |               |
# |    fps                  | 663           |
# |    iterations           | 8             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 2.9601506e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.000934     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.06e+08      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | 1.04e-05      |
# |    std                  | 0.999         |
# |    value_loss           | 1.82e+08      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 398            |
# |    ep_rew_mean          | -1.51e+05      |
# | time/                   |                |
# |    fps                  | 654            |
# |    iterations           | 9              |
# |    time_elapsed         | 28             |
# |    total_timesteps      | 18432          |
# | train/                  |                |
# |    approx_kl            | 0.000117418356 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -0.000153      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.19e+07       |
# |    n_updates            | 80             |
# |    policy_gradient_loss | -4.03e-05      |
# |    std                  | 1              |
# |    value_loss           | 4.78e+07       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 395           |
# |    ep_rew_mean          | -1.55e+05     |
# | time/                   |               |
# |    fps                  | 649           |
# |    iterations           | 10            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 1.0819174e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.00135       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.42e+07      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -2.05e-05     |
# |    std                  | 0.999         |
# |    value_loss           | 6.15e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 410           |
# |    ep_rew_mean          | -1.58e+05     |
# | time/                   |               |
# |    fps                  | 646           |
# |    iterations           | 11            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00013720733 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 4.98e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.75e+07      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00044      |
# |    std                  | 0.999         |
# |    value_loss           | 5.92e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 418          |
# |    ep_rew_mean          | -1.63e+05    |
# | time/                   |              |
# |    fps                  | 640          |
# |    iterations           | 12           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0003313413 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00125     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5e+07      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000187    |
# |    std                  | 1            |
# |    value_loss           | 1.06e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 423          |
# |    ep_rew_mean          | -1.6e+05     |
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 13           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 7.406523e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -1.88e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.55e+07     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 1.06e-05     |
# |    std                  | 1            |
# |    value_loss           | 7.51e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 435           |
# |    ep_rew_mean          | -1.66e+05     |
# | time/                   |               |
# |    fps                  | 637           |
# |    iterations           | 14            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 2.7980364e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.0108       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.61e+07      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000128     |
# |    std                  | 1             |
# |    value_loss           | 3.2e+07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 452          |
# |    ep_rew_mean          | -1.68e+05    |
# | time/                   |              |
# |    fps                  | 639          |
# |    iterations           | 15           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0040877056 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -3.22e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.64e+07     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00266     |
# |    std                  | 1            |
# |    value_loss           | 1.04e+08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 468           |
# |    ep_rew_mean          | -1.64e+05     |
# | time/                   |               |
# |    fps                  | 641           |
# |    iterations           | 16            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00022596552 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | 3.93e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.44e+07      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000302     |
# |    std                  | 1.01          |
# |    value_loss           | 2.72e+07      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | -1.57e+05   |
# | time/                   |             |
# |    fps                  | 640         |
# |    iterations           | 17          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003964814 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 1.98e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67e+05    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00251    |
# |    std                  | 1.01        |
# |    value_loss           | 7.58e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 486         |
# |    ep_rew_mean          | -1.52e+05   |
# | time/                   |             |
# |    fps                  | 640         |
# |    iterations           | 18          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.003312273 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 1.65e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.03e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00291    |
# |    std                  | 1.01        |
# |    value_loss           | 7.71e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | -1.47e+05    |
# | time/                   |              |
# |    fps                  | 643          |
# |    iterations           | 19           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0034317956 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -6.44e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.33e+04     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 1.01         |
# |    value_loss           | 1.76e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 508         |
# |    ep_rew_mean          | -1.43e+05   |
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 20          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005060481 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -8.55e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.73e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.006      |
# |    std                  | 1.01        |
# |    value_loss           | 4.35e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 502          |
# |    ep_rew_mean          | -1.35e+05    |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 21           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0021314267 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -3.22e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.81e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00155     |
# |    std                  | 1.04         |
# |    value_loss           | 1.48e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 491          |
# |    ep_rew_mean          | -1.26e+05    |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 22           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0038670395 |
# |    clip_fraction        | 0.0979       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -1.03e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00146      |
# |    std                  | 1.04         |
# |    value_loss           | 1.04e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 491         |
# |    ep_rew_mean          | -1.21e+05   |
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 23          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.002004466 |
# |    clip_fraction        | 0.00122     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -4.29e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.77e+04    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00163    |
# |    std                  | 1.03        |
# |    value_loss           | 2.06e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 503          |
# |    ep_rew_mean          | -1.18e+05    |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 24           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 8.462943e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -6.79e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.56e+04     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000283    |
# |    std                  | 1.04         |
# |    value_loss           | 1.37e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 508         |
# |    ep_rew_mean          | -1.14e+05   |
# | time/                   |             |
# |    fps                  | 649         |
# |    iterations           | 25          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007907107 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -5.96e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 602         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000939   |
# |    std                  | 1.03        |
# |    value_loss           | 2.31e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 500           |
# |    ep_rew_mean          | -1.03e+05     |
# | time/                   |               |
# |    fps                  | 651           |
# |    iterations           | 26            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00039836427 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -0.0111       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.59e+04      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | 0.0012        |
# |    std                  | 1.03          |
# |    value_loss           | 1.49e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 510           |
# |    ep_rew_mean          | -9.84e+04     |
# | time/                   |               |
# |    fps                  | 654           |
# |    iterations           | 27            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 2.4190726e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -0.142        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.5e+04       |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000144     |
# |    std                  | 1.03          |
# |    value_loss           | 6.36e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 530          |
# |    ep_rew_mean          | -9.88e+04    |
# | time/                   |              |
# |    fps                  | 654          |
# |    iterations           | 28           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 7.155762e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.52e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000187    |
# |    std                  | 1.03         |
# |    value_loss           | 9.1e+03      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 521           |
# |    ep_rew_mean          | -8.55e+04     |
# | time/                   |               |
# |    fps                  | 655           |
# |    iterations           | 29            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 1.8199265e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -2.26e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.33e+05      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.00021      |
# |    std                  | 1.03          |
# |    value_loss           | 2.46e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 530           |
# |    ep_rew_mean          | -7.96e+04     |
# | time/                   |               |
# |    fps                  | 656           |
# |    iterations           | 30            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00020919385 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -5.88e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.03e+04      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000544     |
# |    std                  | 1.03          |
# |    value_loss           | 6.09e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 538           |
# |    ep_rew_mean          | -7.37e+04     |
# | time/                   |               |
# |    fps                  | 655           |
# |    iterations           | 31            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00036042344 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -7.03e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.47e+03      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000232     |
# |    std                  | 1.03          |
# |    value_loss           | 3.85e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 532          |
# |    ep_rew_mean          | -6.88e+04    |
# | time/                   |              |
# |    fps                  | 654          |
# |    iterations           | 32           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0014779773 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -2.62e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.88e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00253     |
# |    std                  | 1.03         |
# |    value_loss           | 3.95e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 551           |
# |    ep_rew_mean          | -6.88e+04     |
# | time/                   |               |
# |    fps                  | 655           |
# |    iterations           | 33            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00026780646 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -5.25e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 242           |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000104     |
# |    std                  | 1.02          |
# |    value_loss           | 878           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 562         |
# |    ep_rew_mean          | -6.3e+04    |
# | time/                   |             |
# |    fps                  | 655         |
# |    iterations           | 34          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008993916 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -5.36e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 517         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00261    |
# |    std                  | 1.02        |
# |    value_loss           | 1.76e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 571           |
# |    ep_rew_mean          | -5.57e+04     |
# | time/                   |               |
# |    fps                  | 656           |
# |    iterations           | 35            |
# |    time_elapsed         | 109           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00038304346 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -7.27e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.22e+03      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 0.000691      |
# |    std                  | 1.02          |
# |    value_loss           | 1.42e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 591          |
# |    ep_rew_mean          | -5.58e+04    |
# | time/                   |              |
# |    fps                  | 655          |
# |    iterations           | 36           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0005342422 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000958    |
# |    std                  | 1.02         |
# |    value_loss           | 3e+04        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 592          |
# |    ep_rew_mean          | -4.99e+04    |
# | time/                   |              |
# |    fps                  | 656          |
# |    iterations           | 37           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0019734344 |
# |    clip_fraction        | 0.00161      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -4.61e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.12e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 1.02         |
# |    value_loss           | 1.11e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 602           |
# |    ep_rew_mean          | -4.97e+04     |
# | time/                   |               |
# |    fps                  | 657           |
# |    iterations           | 38            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00035610437 |
# |    clip_fraction        | 0.00615       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -1.31e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.02e+04      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000866     |
# |    std                  | 1.02          |
# |    value_loss           | 6.61e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 602          |
# |    ep_rew_mean          | -3.95e+04    |
# | time/                   |              |
# |    fps                  | 658          |
# |    iterations           | 39           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0014828538 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.85e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.000183     |
# |    std                  | 1.02         |
# |    value_loss           | 1.04e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 619          |
# |    ep_rew_mean          | -3.89e+04    |
# | time/                   |              |
# |    fps                  | 658          |
# |    iterations           | 40           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0051954906 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 4.77e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 346          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0011      |
# |    std                  | 1.02         |
# |    value_loss           | 1.53e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 619           |
# |    ep_rew_mean          | -3.27e+04     |
# | time/                   |               |
# |    fps                  | 657           |
# |    iterations           | 41            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00047286178 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -8.94e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.93e+04      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000109     |
# |    std                  | 1.02          |
# |    value_loss           | 1.82e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 570           |
# |    ep_rew_mean          | -6.89e+03     |
# | time/                   |               |
# |    fps                  | 658           |
# |    iterations           | 42            |
# |    time_elapsed         | 130           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 3.5220437e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -1.07e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.73e+03      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000235     |
# |    std                  | 1.02          |
# |    value_loss           | 3.57e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 570           |
# |    ep_rew_mean          | -6.25e+03     |
# | time/                   |               |
# |    fps                  | 658           |
# |    iterations           | 43            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 1.9503379e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -3.22e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.94e+04      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -7.32e-06     |
# |    std                  | 1.02          |
# |    value_loss           | 1.12e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 560          |
# |    ep_rew_mean          | -5.56e+03    |
# | time/                   |              |
# |    fps                  | 658          |
# |    iterations           | 44           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 8.368128e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+04     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000142    |
# |    std                  | 1.02         |
# |    value_loss           | 3e+04        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 570          |
# |    ep_rew_mean          | -4.94e+03    |
# | time/                   |              |
# |    fps                  | 659          |
# |    iterations           | 45           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0008099064 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.1e+03      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000862    |
# |    std                  | 1.02         |
# |    value_loss           | 1.63e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 569         |
# |    ep_rew_mean          | -4.94e+03   |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 46          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.001576367 |
# |    clip_fraction        | 0.000635    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.99e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.000615   |
# |    std                  | 1.02        |
# |    value_loss           | 1.5e+04     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 567           |
# |    ep_rew_mean          | -4.36e+03     |
# | time/                   |               |
# |    fps                  | 662           |
# |    iterations           | 47            |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00041392026 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.17e+04      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000382     |
# |    std                  | 1.02          |
# |    value_loss           | 5.63e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 550          |
# |    ep_rew_mean          | -4.36e+03    |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 48           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0041338457 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -1.06e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 675          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.000641     |
# |    std                  | 1.02         |
# |    value_loss           | 2.49e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 560          |
# |    ep_rew_mean          | -4.55e+03    |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 49           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0007628531 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -2.26e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46e+04     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000329     |
# |    std                  | 1.03         |
# |    value_loss           | 3.45e+04     |
# ------------------------------------------

# %%
# Load the trained model
model = PPO.load("ppo_line_follower")

# Test the model
env = LineFollowingEnv(C1=1.0, C2=0.01)
obs = env.reset()
done = False

while not done:
    action, _ = model.predict(obs)
    obs, reward, done, _ = env.step(action)
    env.render()
    print (action)
# Out:
# Step: 1, d: -0.6098095178604126, theta: 58.52007293701172
# [0.08950257]
# Step: 2, d: -0.5659797191619873, theta: 61.23443603515625
# [0.54287237]
# Step: 3, d: -0.5231448411941528, theta: 58.947845458984375
# [-0.4573177]
# Step: 4, d: -0.48086291551589966, theta: 57.74041748046875
# [-0.24148586]
# Step: 5, d: -0.4390176832675934, theta: 56.814666748046875
# [-0.18515024]
# Step: 6, d: -0.39971691370010376, theta: 51.814666748046875
# [-1.]
# Step: 7, d: -0.3590337336063385, theta: 54.455413818359375
# [0.5281492]
# Step: 8, d: -0.32103872299194336, theta: 49.455413818359375
# [-1.]
# Step: 9, d: -0.28602102398872375, theta: 44.455413818359375
# [-1.]
# Step: 10, d: -0.25424712896347046, theta: 39.455413818359375
# [-1.]
# Step: 11, d: -0.22595888376235962, theta: 34.455413818359375
# [-1.]
# Step: 12, d: -0.19741246104240417, theta: 34.814998626708984
# [0.0719167]
# Step: 13, d: -0.1674596220254898, theta: 36.8023796081543
# [0.39747655]
# Step: 14, d: -0.13653889298439026, theta: 38.200443267822266
# [0.27961272]
# Step: 15, d: -0.1091604083776474, theta: 33.200443267822266
# [-1.]
# Step: 16, d: -0.08320403099060059, theta: 31.27375030517578
# [-0.38533854]
# Step: 17, d: -0.05827443301677704, theta: 29.906885147094727
# [-0.27337313]
# Step: 18, d: -0.035555966198444366, theta: 27.02435874938965
# [-0.57650524]
# C:\Users\brend\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
model.action_space
# Out:
# Box(-1.0, 1.0, (1,), float32)
