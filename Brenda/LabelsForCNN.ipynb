# %%
import cv2
import numpy as np
import os
import csv
from datetime import datetime

def classify_and_save_image(image):
    # Create output folders if they don't exist
    categories = ['left', 'slight_left', 'center', 'slight_right', 'right']
    for category in categories:
        os.makedirs(os.path.join(category), exist_ok=True)

    # Get image dimensions
    height, width = image.shape
    section_width = width // 5

    # Count white pixels in each section
    white_counts = [np.sum(image[:, i * section_width: (i + 1) * section_width] == 255) for i in range(5)]

    # Determine the section with the most white pixels
    max_index = np.argmax(white_counts)
    category = categories[max_index]

    # Save the image with a unique name
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S%f')
    output_path = os.path.join(category, f"{timestamp}.png")
    cv2.imwrite(output_path, image)

    print(f"Image saved to {output_path} under category '{category}'")


# Example usage
# classify_and_save_image('path_to_image.png', 'output_folder')
def store_image(folder, image):
    """Stores an image in the specified folder with a timestamp-based filename."""
    os.makedirs(folder, exist_ok=True)  # Create folder if it doesn't exist

    # Generate a unique filename using date and time
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")+f"_{datetime.now().microsecond // 1000}"
    filename = f"{folder}/image_{timestamp}.png"

    # Save image
    cv2.imwrite(filename, image)
    
def cut_images(folder, image):
    """Detects the centerline of a white line in a black background and returns (x, y) points."""
    height, width = image.shape[:2]
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    row_index = 0
    # Region of interest (ROI) is the top half of the image as the robot only moves forward
    for i in range(4):
        roi = gray[row_index:row_index+50, :] 
        row_index += 50
        # Threshold to isolate the white line
        _, binary = cv2.threshold(roi, 200, 255, cv2.THRESH_BINARY)
        classify_and_save_image(binary)
        classify_and_save_image(cv2.flip(binary, 1))

def calculate_angle(centerline):
    """Calculates the angle of the white line with respect to the vertical axis."""
    
    if len(centerline) < 2:
        return None  # Not enough points to calculate angle

    # Fit a line using linear regression
    x_coords = np.array([p[0] for p in centerline])
    y_coords = np.array([p[1] for p in centerline])
    
    # Fit a line: y = mx + b
    m, b = np.polyfit(x_coords, y_coords, 1)  # Slope and intercept

    # Calculate angle from vertical axis
    angle_rad = np.arctan(m)
    angle_deg = np.degrees(angle_rad)

    return angle_deg

def process_images(folder, processed_folder):
    """Processes all images in a folder and saves centerline points + angle."""
    
    if not os.path.exists(folder):
        print("Folder does not exist.")
        return

    image_files = [f for f in os.listdir(folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    if not image_files:
        print("No images found.")
        return

    for filename in image_files:
        image_path = os.path.join(folder, filename)
        image = cv2.imread(image_path)

        if image is None:
            print(f"Failed to read {filename}")
            continue

        cut_images(processed_folder, image)

# %%
process_images("images", "processed")
# Out:
# Image saved to center\20250319_204251678496.png under category 'center'
# Image saved to center\20250319_204251681026.png under category 'center'
# Image saved to center\20250319_204251683044.png under category 'center'
# Image saved to center\20250319_204251685042.png under category 'center'
# Image saved to center\20250319_204251686043.png under category 'center'
# Image saved to center\20250319_204251688041.png under category 'center'
# Image saved to center\20250319_204251689042.png under category 'center'
# Image saved to center\20250319_204251690042.png under category 'center'
# Image saved to center\20250319_204251693393.png under category 'center'
# Image saved to center\20250319_204251695022.png under category 'center'
# Image saved to center\20250319_204251695620.png under category 'center'
# Image saved to center\20250319_204251695620.png under category 'center'
# Image saved to center\20250319_204251698188.png under category 'center'
# Image saved to center\20250319_204251699197.png under category 'center'
# Image saved to center\20250319_204251700703.png under category 'center'
# Image saved to center\20250319_204251701710.png under category 'center'
# Image saved to right\20250319_204251704647.png under category 'right'
# Image saved to left\20250319_204251705643.png under category 'left'
# Image saved to slight_right\20250319_204251706643.png under category 'slight_right'
# Image saved to slight_left\20250319_204251707642.png under category 'slight_left'
# Image saved to slight_right\20250319_204251708643.png under category 'slight_right'
# Image saved to slight_left\20250319_204251710149.png under category 'slight_left'
# Image saved to slight_right\20250319_204251711154.png under category 'slight_right'
# Image saved to slight_left\20250319_204251712155.png under category 'slight_left'
# Image saved to slight_right\20250319_204251714154.png under category 'slight_right'
# Image saved to slight_left\20250319_204251715155.png under category 'slight_left'
# Image saved to slight_right\20250319_204251717157.png under category 'slight_right'
# Image saved to slight_left\20250319_204251718155.png under category 'slight_left'
# Image saved to slight_right\20250319_204251719155.png under category 'slight_right'
# Image saved to slight_left\20250319_204251720077.png under category 'slight_left'
# Image saved to slight_right\20250319_204251720077.png under category 'slight_right'
# Image saved to slight_left\20250319_204251720077.png under category 'slight_left'
# Image saved to slight_right\20250319_204251723287.png under category 'slight_right'
# Image saved to slight_left\20250319_204251723287.png under category 'slight_left'
# Image saved to slight_right\20250319_204251723287.png under category 'slight_right'
# Image saved to slight_left\20250319_204251727310.png under category 'slight_left'
# Image saved to slight_right\20250319_204251727310.png under category 'slight_right'
# Image saved to slight_left\20250319_204251727310.png under category 'slight_left'
# Image saved to slight_right\20250319_204251730227.png under category 'slight_right'
# Image saved to slight_left\20250319_204251731546.png under category 'slight_left'
# Image saved to slight_right\20250319_204251733553.png under category 'slight_right'
# Image saved to slight_left\20250319_204251734554.png under category 'slight_left'
# Image saved to slight_right\20250319_204251735553.png under category 'slight_right'
# Image saved to slight_left\20250319_204251736553.png under category 'slight_left'
# Image saved to slight_right\20250319_204251737439.png under category 'slight_right'
# Image saved to slight_left\20250319_204251737439.png under category 'slight_left'
# Image saved to slight_right\20250319_204251737439.png under category 'slight_right'
# Image saved to slight_left\20250319_204251740371.png under category 'slight_left'
# Image saved to right\20250319_204251742439.png under category 'right'
# Image saved to left\20250319_204251742439.png under category 'left'
# Image saved to right\20250319_204251744446.png under category 'right'
# Image saved to left\20250319_204251744446.png under category 'left'
# Image saved to right\20250319_204251744446.png under category 'right'
# Image saved to left\20250319_204251744446.png under category 'left'
# Image saved to right\20250319_204251748157.png under category 'right'
# Image saved to left\20250319_204251748644.png under category 'left'
# Image saved to right\20250319_204251750150.png under category 'right'
# Image saved to left\20250319_204251752175.png under category 'left'
# Image saved to right\20250319_204251752175.png under category 'right'
# Image saved to left\20250319_204251752175.png under category 'left'
# Image saved to right\20250319_204251752175.png under category 'right'
# Image saved to left\20250319_204251756187.png under category 'left'
# Image saved to slight_right\20250319_204251756187.png under category 'slight_right'
# Image saved to slight_left\20250319_204251756187.png under category 'slight_left'
# Image saved to right\20250319_204251756187.png under category 'right'
# Image saved to left\20250319_204251760376.png under category 'left'
# Image saved to right\20250319_204251760376.png under category 'right'
# Image saved to left\20250319_204251760376.png under category 'left'
# Image saved to right\20250319_204251760376.png under category 'right'
# Image saved to left\20250319_204251760376.png under category 'left'
# Image saved to right\20250319_204251764856.png under category 'right'
# Image saved to left\20250319_204251765859.png under category 'left'
# Image saved to right\20250319_204251767861.png under category 'right'
# Image saved to left\20250319_204251768858.png under category 'left'
# Image saved to right\20250319_204251770366.png under category 'right'
# Image saved to left\20250319_204251770366.png under category 'left'
# Image saved to right\20250319_204251771373.png under category 'right'
# Image saved to left\20250319_204251772374.png under category 'left'
# Image saved to right\20250319_204251773372.png under category 'right'
# Image saved to left\20250319_204251774371.png under category 'left'
# Image saved to right\20250319_204251775373.png under category 'right'
# Image saved to left\20250319_204251775373.png under category 'left'
# Image saved to right\20250319_204251775373.png under category 'right'
# Image saved to left\20250319_204251780102.png under category 'left'
# Image saved to right\20250319_204251781440.png under category 'right'
# Image saved to left\20250319_204251782446.png under category 'left'
# Image saved to right\20250319_204251782969.png under category 'right'
# Image saved to left\20250319_204251782969.png under category 'left'
# Image saved to slight_right\20250319_204251786488.png under category 'slight_right'
# Image saved to slight_left\20250319_204251786488.png under category 'slight_left'
# Image saved to slight_right\20250319_204251786488.png under category 'slight_right'
# Image saved to slight_left\20250319_204251786488.png under category 'slight_left'
# Image saved to slight_right\20250319_204251786488.png under category 'slight_right'
# Image saved to slight_left\20250319_204251790183.png under category 'slight_left'
# Image saved to slight_right\20250319_204251790183.png under category 'slight_right'
# Image saved to slight_left\20250319_204251792210.png under category 'slight_left'
# Image saved to slight_right\20250319_204251794220.png under category 'slight_right'
# Image saved to slight_left\20250319_204251794220.png under category 'slight_left'
# Image saved to slight_right\20250319_204251794220.png under category 'slight_right'
# Image saved to slight_left\20250319_204251794220.png under category 'slight_left'
# Image saved to slight_right\20250319_204251798152.png under category 'slight_right'
# Image saved to slight_left\20250319_204251799160.png under category 'slight_left'
# Image saved to slight_right\20250319_204251800160.png under category 'slight_right'
# Image saved to slight_left\20250319_204251801232.png under category 'slight_left'
# Image saved to slight_right\20250319_204251801232.png under category 'slight_right'
# Image saved to slight_left\20250319_204251801232.png under category 'slight_left'
# Image saved to slight_right\20250319_204251804612.png under category 'slight_right'
# Image saved to slight_left\20250319_204251804612.png under category 'slight_left'
# Image saved to slight_right\20250319_204251804612.png under category 'slight_right'
# Image saved to slight_left\20250319_204251804612.png under category 'slight_left'
# Image saved to slight_right\20250319_204251804612.png under category 'slight_right'
# Image saved to slight_left\20250319_204251809375.png under category 'slight_left'
# Image saved to center\20250319_204251811033.png under category 'center'
# Image saved to center\20250319_204251812034.png under category 'center'
# Image saved to center\20250319_204251813038.png under category 'center'
# Image saved to center\20250319_204251814038.png under category 'center'
# Image saved to slight_right\20250319_204251815040.png under category 'slight_right'
# Image saved to slight_left\20250319_204251816040.png under category 'slight_left'
# Image saved to slight_right\20250319_204251817040.png under category 'slight_right'
# Image saved to slight_left\20250319_204251818042.png under category 'slight_left'
# Image saved to right\20250319_204251820038.png under category 'right'
# Image saved to left\20250319_204251821170.png under category 'left'
# Image saved to right\20250319_204251822169.png under category 'right'
# Image saved to left\20250319_204251823169.png under category 'left'
# Image saved to slight_right\20250319_204251824169.png under category 'slight_right'
# Image saved to slight_left\20250319_204251825172.png under category 'slight_left'
# Image saved to slight_right\20250319_204251826170.png under category 'slight_right'
# Image saved to slight_left\20250319_204251827169.png under category 'slight_left'
# Image saved to right\20250319_204251829170.png under category 'right'
# Image saved to left\20250319_204251830170.png under category 'left'
# Image saved to right\20250319_204251830676.png under category 'right'
# Image saved to left\20250319_204251831681.png under category 'left'
# Image saved to right\20250319_204251832974.png under category 'right'
# Image saved to left\20250319_204251833981.png under category 'left'
# Image saved to right\20250319_204251834982.png under category 'right'
# Image saved to left\20250319_204251835980.png under category 'left'
# Image saved to right\20250319_204251837984.png under category 'right'
# Image saved to left\20250319_204251838979.png under category 'left'
# Image saved to right\20250319_204251839979.png under category 'right'
# Image saved to left\20250319_204251841490.png under category 'left'
# Image saved to right\20250319_204251842490.png under category 'right'
# Image saved to left\20250319_204251843491.png under category 'left'
# Image saved to right\20250319_204251844488.png under category 'right'
# Image saved to left\20250319_204251845489.png under category 'left'
# Image saved to right\20250319_204251847489.png under category 'right'
# Image saved to left\20250319_204251848490.png under category 'left'
# Image saved to right\20250319_204251848490.png under category 'right'
# Image saved to left\20250319_204251850081.png under category 'left'
# Image saved to right\20250319_204251850081.png under category 'right'
# Image saved to left\20250319_204251852623.png under category 'left'
# Image saved to right\20250319_204251852623.png under category 'right'
# Image saved to left\20250319_204251852623.png under category 'left'
# Image saved to left\20250319_204251856639.png under category 'left'
# Image saved to left\20250319_204251856639.png under category 'left'
# Image saved to right\20250319_204251856639.png under category 'right'
# Image saved to left\20250319_204251856639.png under category 'left'
# Image saved to right\20250319_204251860240.png under category 'right'
# Image saved to left\20250319_204251860240.png under category 'left'
# Image saved to right\20250319_204251860240.png under category 'right'
# Image saved to left\20250319_204251860240.png under category 'left'
# Image saved to left\20250319_204251864847.png under category 'left'
# Image saved to left\20250319_204251866847.png under category 'left'
# Image saved to left\20250319_204251867848.png under category 'left'
# Image saved to left\20250319_204251867848.png under category 'left'
# Image saved to left\20250319_204251870477.png under category 'left'
# Image saved to left\20250319_204251870477.png under category 'left'
# Image saved to left\20250319_204251872223.png under category 'left'
# Image saved to left\20250319_204251872223.png under category 'left'
# Image saved to right\20250319_204251872223.png under category 'right'
# Image saved to left\20250319_204251876237.png under category 'left'
# Image saved to right\20250319_204251876237.png under category 'right'
# Image saved to left\20250319_204251876237.png under category 'left'
# Image saved to right\20250319_204251876237.png under category 'right'
# Image saved to left\20250319_204251876237.png under category 'left'
# Image saved to right\20250319_204251880187.png under category 'right'
# Image saved to left\20250319_204251881536.png under category 'left'
# Image saved to slight_right\20250319_204251883716.png under category 'slight_right'
# Image saved to slight_left\20250319_204251884686.png under category 'slight_left'
# Image saved to slight_right\20250319_204251884686.png under category 'slight_right'
# Image saved to slight_left\20250319_204251884686.png under category 'slight_left'
# Image saved to slight_right\20250319_204251887761.png under category 'slight_right'
# Image saved to slight_left\20250319_204251887761.png under category 'slight_left'
# Image saved to slight_right\20250319_204251887761.png under category 'slight_right'
# Image saved to slight_left\20250319_204251890267.png under category 'slight_left'
# Image saved to slight_right\20250319_204251892013.png under category 'slight_right'
# Image saved to slight_left\20250319_204251894020.png under category 'slight_left'
# Image saved to slight_right\20250319_204251894020.png under category 'slight_right'
# Image saved to slight_left\20250319_204251894020.png under category 'slight_left'
# Image saved to slight_right\20250319_204251896027.png under category 'slight_right'
# Image saved to slight_left\20250319_204251896027.png under category 'slight_left'
# Image saved to slight_right\20250319_204251898164.png under category 'slight_right'
# Image saved to slight_left\20250319_204251899172.png under category 'slight_left'
# Image saved to slight_right\20250319_204251900676.png under category 'slight_right'
# Image saved to slight_left\20250319_204251902108.png under category 'slight_left'
# Image saved to slight_right\20250319_204251902108.png under category 'slight_right'
# Image saved to slight_left\20250319_204251902108.png under category 'slight_left'
# Image saved to right\20250319_204251905930.png under category 'right'
# Image saved to left\20250319_204251906581.png under category 'left'
# Image saved to slight_right\20250319_204251908588.png under category 'slight_right'
# Image saved to slight_left\20250319_204251910221.png under category 'slight_left'
# Image saved to right\20250319_204251912229.png under category 'right'
# Image saved to left\20250319_204251913227.png under category 'left'
# Image saved to right\20250319_204251914228.png under category 'right'
# Image saved to left\20250319_204251916228.png under category 'left'
# Image saved to right\20250319_204251917228.png under category 'right'
# Image saved to left\20250319_204251919231.png under category 'left'
# Image saved to right\20250319_204251921009.png under category 'right'
# Image saved to left\20250319_204251921009.png under category 'left'
# Image saved to slight_right\20250319_204251924349.png under category 'slight_right'
# Image saved to slight_left\20250319_204251924349.png under category 'slight_left'
# Image saved to slight_right\20250319_204251924349.png under category 'slight_right'
# Image saved to slight_left\20250319_204251924349.png under category 'slight_left'
# Image saved to slight_right\20250319_204251928371.png under category 'slight_right'
# Image saved to slight_left\20250319_204251928371.png under category 'slight_left'
# Image saved to slight_right\20250319_204251930376.png under category 'slight_right'
# Image saved to slight_left\20250319_204251931539.png under category 'slight_left'
# Image saved to right\20250319_204251934545.png under category 'right'
# Image saved to left\20250319_204251935546.png under category 'left'
# Image saved to right\20250319_204251937545.png under category 'right'
# Image saved to left\20250319_204251938546.png under category 'left'
# Image saved to right\20250319_204251938546.png under category 'right'
# Image saved to left\20250319_204251940051.png under category 'left'
# Image saved to right\20250319_204251942059.png under category 'right'
# Image saved to left\20250319_204251943056.png under category 'left'
# Image saved to right\20250319_204251945057.png under category 'right'
# Image saved to left\20250319_204251946057.png under category 'left'
# Image saved to right\20250319_204251947057.png under category 'right'
# Image saved to left\20250319_204251948713.png under category 'left'
# Image saved to right\20250319_204251950219.png under category 'right'
# Image saved to left\20250319_204251950219.png under category 'left'
# Image saved to right\20250319_204251950219.png under category 'right'
# Image saved to left\20250319_204251952246.png under category 'left'
# Image saved to right\20250319_204251952246.png under category 'right'
# Image saved to left\20250319_204251955139.png under category 'left'
# Image saved to right\20250319_204251956645.png under category 'right'
# Image saved to left\20250319_204251956645.png under category 'left'
# Image saved to right\20250319_204251956645.png under category 'right'
# Image saved to left\20250319_204251956645.png under category 'left'
# Image saved to right\20250319_204251961009.png under category 'right'
# Image saved to left\20250319_204251961009.png under category 'left'
# Image saved to right\20250319_204251961009.png under category 'right'
# Image saved to left\20250319_204251964856.png under category 'left'
# Image saved to right\20250319_204251966157.png under category 'right'
# Image saved to left\20250319_204251967166.png under category 'left'
# Image saved to right\20250319_204251968164.png under category 'right'
# Image saved to left\20250319_204251969165.png under category 'left'
# Image saved to right\20250319_204251970337.png under category 'right'
# Image saved to left\20250319_204251970337.png under category 'left'
# Image saved to right\20250319_204251974535.png under category 'right'
# Image saved to left\20250319_204251975302.png under category 'left'
# Image saved to right\20250319_204251976323.png under category 'right'
# Image saved to left\20250319_204251977322.png under category 'left'
# Image saved to right\20250319_204251978323.png under category 'right'
# Image saved to left\20250319_204251979320.png under category 'left'
# Image saved to right\20250319_204251980320.png under category 'right'
# Image saved to left\20250319_204251981716.png under category 'left'
# Image saved to right\20250319_204251984723.png under category 'right'
# Image saved to left\20250319_204251985718.png under category 'left'
# Image saved to right\20250319_204251986717.png under category 'right'
# Image saved to left\20250319_204251987714.png under category 'left'
# Image saved to right\20250319_204251988715.png under category 'right'
# Image saved to left\20250319_204251988715.png under category 'left'
# Image saved to right\20250319_204251990220.png under category 'right'
# Image saved to left\20250319_204251991226.png under category 'left'
# Image saved to slight_right\20250319_204251993227.png under category 'slight_right'
# Image saved to slight_left\20250319_204251994228.png under category 'slight_left'
# Image saved to right\20250319_204251995227.png under category 'right'
# Image saved to left\20250319_204251996227.png under category 'left'
# Image saved to right\20250319_204251998226.png under category 'right'
# Image saved to left\20250319_204251999226.png under category 'left'
# Image saved to right\20250319_204252000226.png under category 'right'
# Image saved to left\20250319_204252001552.png under category 'left'
# Image saved to slight_right\20250319_204252003551.png under category 'slight_right'
# Image saved to slight_left\20250319_204252004550.png under category 'slight_left'
# Image saved to slight_right\20250319_204252005550.png under category 'slight_right'
# Image saved to slight_left\20250319_204252006549.png under category 'slight_left'
# Image saved to slight_right\20250319_204252007550.png under category 'slight_right'
# Image saved to slight_left\20250319_204252008550.png under category 'slight_left'
# Image saved to slight_right\20250319_204252008550.png under category 'slight_right'
# Image saved to slight_left\20250319_204252010055.png under category 'slight_left'
# Image saved to slight_right\20250319_204252012059.png under category 'slight_right'
# Image saved to slight_left\20250319_204252012059.png under category 'slight_left'
# Image saved to slight_right\20250319_204252014063.png under category 'slight_right'
# Image saved to slight_left\20250319_204252015061.png under category 'slight_left'
# Image saved to slight_right\20250319_204252015061.png under category 'slight_right'
# Image saved to slight_left\20250319_204252015061.png under category 'slight_left'
# Image saved to slight_right\20250319_204252015061.png under category 'slight_right'
# Image saved to slight_left\20250319_204252015061.png under category 'slight_left'
# Image saved to center\20250319_204252020298.png under category 'center'
# Image saved to center\20250319_204252020298.png under category 'center'
# Image saved to center\20250319_204252020298.png under category 'center'
# Image saved to center\20250319_204252023302.png under category 'center'
# Image saved to center\20250319_204252023302.png under category 'center'
# Image saved to center\20250319_204252023302.png under category 'center'
# Image saved to center\20250319_204252023302.png under category 'center'
# Image saved to center\20250319_204252026318.png under category 'center'
# Image saved to left\20250319_204252027325.png under category 'left'
# Image saved to left\20250319_204252027325.png under category 'left'
# Image saved to left\20250319_204252027325.png under category 'left'
# Image saved to left\20250319_204252030352.png under category 'left'
# Image saved to right\20250319_204252031381.png under category 'right'
# Image saved to left\20250319_204252032509.png under category 'left'
# Image saved to right\20250319_204252034508.png under category 'right'
# Image saved to left\20250319_204252035512.png under category 'left'
# Image saved to left\20250319_204252037511.png under category 'left'
# Image saved to left\20250319_204252038508.png under category 'left'
# Image saved to left\20250319_204252038508.png under category 'left'
# Image saved to left\20250319_204252040019.png under category 'left'
# Image saved to left\20250319_204252041027.png under category 'left'
# Image saved to left\20250319_204252042384.png under category 'left'
# Image saved to left\20250319_204252042384.png under category 'left'
# Image saved to left\20250319_204252042384.png under category 'left'
# Image saved to left\20250319_204252046396.png under category 'left'
# Image saved to left\20250319_204252046396.png under category 'left'
# Image saved to left\20250319_204252048114.png under category 'left'
# Image saved to left\20250319_204252049120.png under category 'left'
# Image saved to left\20250319_204252050123.png under category 'left'
# Image saved to left\20250319_204252050123.png under category 'left'
# Image saved to left\20250319_204252053177.png under category 'left'
# Image saved to left\20250319_204252053177.png under category 'left'
# Image saved to left\20250319_204252055184.png under category 'left'
# Image saved to left\20250319_204252055184.png under category 'left'
# Image saved to left\20250319_204252057191.png under category 'left'
# Image saved to left\20250319_204252057191.png under category 'left'
# Image saved to left\20250319_204252057191.png under category 'left'
# Image saved to left\20250319_204252059197.png under category 'left'
# Image saved to left\20250319_204252060205.png under category 'left'
# Image saved to left\20250319_204252061235.png under category 'left'
# Image saved to left\20250319_204252063348.png under category 'left'
# Image saved to left\20250319_204252063348.png under category 'left'
# Image saved to left\20250319_204252064842.png under category 'left'
# Image saved to left\20250319_204252065266.png under category 'left'
# Image saved to left\20250319_204252065266.png under category 'left'
# Image saved to left\20250319_204252065266.png under category 'left'
# Image saved to left\20250319_204252068969.png under category 'left'
# Image saved to left\20250319_204252069976.png under category 'left'
# Image saved to left\20250319_204252072007.png under category 'left'
# Image saved to right\20250319_204252073674.png under category 'right'
# Image saved to left\20250319_204252073674.png under category 'left'
# Image saved to right\20250319_204252073674.png under category 'right'
# Image saved to left\20250319_204252073674.png under category 'left'
# Image saved to right\20250319_204252077305.png under category 'right'
# Image saved to left\20250319_204252077305.png under category 'left'
# Image saved to left\20250319_204252077305.png under category 'left'
# Image saved to left\20250319_204252081364.png under category 'left'
# Image saved to center\20250319_204252081937.png under category 'center'
# Image saved to left\20250319_204252081937.png under category 'left'
# Image saved to center\20250319_204252081937.png under category 'center'
# Image saved to left\20250319_204252085377.png under category 'left'
# Image saved to center\20250319_204252085377.png under category 'center'
# Image saved to left\20250319_204252085377.png under category 'left'
# Image saved to center\20250319_204252087550.png under category 'center'
# Image saved to center\20250319_204252089556.png under category 'center'
# Image saved to center\20250319_204252090061.png under category 'center'
# Image saved to center\20250319_204252090061.png under category 'center'
# Image saved to center\20250319_204252090061.png under category 'center'
# Image saved to center\20250319_204252093925.png under category 'center'
# Image saved to center\20250319_204252093925.png under category 'center'
# Image saved to center\20250319_204252093925.png under category 'center'
# Image saved to center\20250319_204252093925.png under category 'center'
# Image saved to center\20250319_204252098672.png under category 'center'
# Image saved to center\20250319_204252100183.png under category 'center'
# Image saved to center\20250319_204252102669.png under category 'center'
# Image saved to center\20250319_204252102669.png under category 'center'
# Image saved to center\20250319_204252102669.png under category 'center'
# Image saved to center\20250319_204252102669.png under category 'center'
# Image saved to center\20250319_204252102669.png under category 'center'
# Image saved to center\20250319_204252107143.png under category 'center'
# Image saved to center\20250319_204252107143.png under category 'center'
# Image saved to center\20250319_204252110163.png under category 'center'
# Image saved to center\20250319_204252111209.png under category 'center'
# Image saved to center\20250319_204252111209.png under category 'center'
# Image saved to center\20250319_204252113717.png under category 'center'
# Image saved to center\20250319_204252115724.png under category 'center'
# Image saved to center\20250319_204252115724.png under category 'center'
# Image saved to center\20250319_204252115724.png under category 'center'
# Image saved to center\20250319_204252120098.png under category 'center'
# Image saved to center\20250319_204252120098.png under category 'center'
# Image saved to center\20250319_204252120098.png under category 'center'
# Image saved to center\20250319_204252120098.png under category 'center'
# Image saved to center\20250319_204252120098.png under category 'center'
# Image saved to center\20250319_204252120098.png under category 'center'
# Image saved to center\20250319_204252124192.png under category 'center'
# Image saved to center\20250319_204252124192.png under category 'center'
# Image saved to center\20250319_204252124192.png under category 'center'
# Image saved to center\20250319_204252128445.png under category 'center'
# Image saved to center\20250319_204252129951.png under category 'center'
# Image saved to center\20250319_204252131524.png under category 'center'
# Image saved to center\20250319_204252132531.png under category 'center'
# Image saved to center\20250319_204252133531.png under category 'center'
# Image saved to center\20250319_204252135531.png under category 'center'
# Image saved to center\20250319_204252135531.png under category 'center'
# Image saved to center\20250319_204252137755.png under category 'center'
# Image saved to center\20250319_204252138753.png under category 'center'
# Image saved to center\20250319_204252140259.png under category 'center'
# Image saved to center\20250319_204252141265.png under category 'center'
# Image saved to center\20250319_204252142266.png under category 'center'
# Image saved to center\20250319_204252143266.png under category 'center'
# Image saved to center\20250319_204252144265.png under category 'center'
# Image saved to center\20250319_204252145264.png under category 'center'
# Image saved to center\20250319_204252147265.png under category 'center'
# Image saved to center\20250319_204252148265.png under category 'center'
# Image saved to center\20250319_204252149267.png under category 'center'
# Image saved to center\20250319_204252150265.png under category 'center'
# Image saved to center\20250319_204252151493.png under category 'center'
# Image saved to center\20250319_204252153494.png under category 'center'
# Image saved to center\20250319_204252154495.png under category 'center'
# Image saved to center\20250319_204252155494.png under category 'center'
# Image saved to center\20250319_204252157499.png under category 'center'
# Image saved to center\20250319_204252158494.png under category 'center'
# Image saved to center\20250319_204252160000.png under category 'center'
# Image saved to center\20250319_204252161009.png under category 'center'
# Image saved to center\20250319_204252162006.png under category 'center'
# Image saved to center\20250319_204252163007.png under category 'center'
# Image saved to center\20250319_204252164005.png under category 'center'
# Image saved to center\20250319_204252165005.png under category 'center'
# Image saved to center\20250319_204252167005.png under category 'center'
# Image saved to center\20250319_204252168008.png under category 'center'
# Image saved to center\20250319_204252169005.png under category 'center'
# Image saved to center\20250319_204252170008.png under category 'center'
# Image saved to center\20250319_204252172064.png under category 'center'
# Image saved to center\20250319_204252173063.png under category 'center'
# Image saved to center\20250319_204252174063.png under category 'center'
# Image saved to center\20250319_204252175063.png under category 'center'
# Image saved to slight_right\20250319_204252177064.png under category 'slight_right'
# Image saved to slight_left\20250319_204252178063.png under category 'slight_left'
# Image saved to slight_left\20250319_204252179063.png under category 'slight_left'
# Image saved to slight_right\20250319_204252180569.png under category 'slight_right'
# Image saved to center\20250319_204252180569.png under category 'center'
# Image saved to center\20250319_204252182028.png under category 'center'
# Image saved to center\20250319_204252182028.png under category 'center'
# Image saved to center\20250319_204252182028.png under category 'center'
# Image saved to center\20250319_204252185673.png under category 'center'
# Image saved to center\20250319_204252185673.png under category 'center'
# Image saved to center\20250319_204252185673.png under category 'center'
# Image saved to center\20250319_204252185673.png under category 'center'
# Image saved to center\20250319_204252185673.png under category 'center'
# Image saved to center\20250319_204252190207.png under category 'center'
# Image saved to center\20250319_204252190207.png under category 'center'
# Image saved to center\20250319_204252190207.png under category 'center'
# Image saved to center\20250319_204252190207.png under category 'center'
# Image saved to center\20250319_204252194373.png under category 'center'
# Image saved to center\20250319_204252194373.png under category 'center'
# Image saved to center\20250319_204252194373.png under category 'center'
# Image saved to center\20250319_204252194373.png under category 'center'
# Image saved to center\20250319_204252198168.png under category 'center'
# Image saved to center\20250319_204252199952.png under category 'center'
# Image saved to center\20250319_204252201084.png under category 'center'
# Image saved to center\20250319_204252203084.png under category 'center'
# Image saved to center\20250319_204252204087.png under category 'center'
# Image saved to center\20250319_204252205084.png under category 'center'
# Image saved to center\20250319_204252206083.png under category 'center'
# Image saved to center\20250319_204252207085.png under category 'center'
# Image saved to center\20250319_204252208084.png under category 'center'
# Image saved to center\20250319_204252209083.png under category 'center'
# Image saved to center\20250319_204252211227.png under category 'center'
# Image saved to center\20250319_204252213225.png under category 'center'
# Image saved to center\20250319_204252214229.png under category 'center'
# Image saved to center\20250319_204252215228.png under category 'center'
# Image saved to center\20250319_204252217229.png under category 'center'
# Image saved to center\20250319_204252218227.png under category 'center'
# Image saved to center\20250319_204252219227.png under category 'center'
# Image saved to center\20250319_204252219227.png under category 'center'
# Image saved to center\20250319_204252220229.png under category 'center'
# Image saved to slight_right\20250319_204252223732.png under category 'slight_right'
# Image saved to slight_left\20250319_204252224731.png under category 'slight_left'
# Image saved to slight_right\20250319_204252225730.png under category 'slight_right'
# Image saved to slight_left\20250319_204252227729.png under category 'slight_left'
# Image saved to slight_right\20250319_204252228730.png under category 'slight_right'
# Image saved to slight_left\20250319_204252230234.png under category 'slight_left'
# Image saved to slight_right\20250319_204252231240.png under category 'slight_right'
# Image saved to slight_left\20250319_204252232433.png under category 'slight_left'
# Image saved to slight_right\20250319_204252234440.png under category 'slight_right'
# Image saved to slight_left\20250319_204252235260.png under category 'slight_left'
# Image saved to slight_right\20250319_204252235260.png under category 'slight_right'
# Image saved to slight_left\20250319_204252235260.png under category 'slight_left'
# Image saved to slight_right\20250319_204252238670.png under category 'slight_right'
# Image saved to slight_left\20250319_204252240176.png under category 'slight_left'
# Image saved to slight_right\20250319_204252240176.png under category 'slight_right'
# Image saved to slight_left\20250319_204252240176.png under category 'slight_left'
# Image saved to slight_right\20250319_204252242839.png under category 'slight_right'
# Image saved to slight_left\20250319_204252242839.png under category 'slight_left'
# Image saved to slight_right\20250319_204252242839.png under category 'slight_right'
# Image saved to slight_left\20250319_204252246881.png under category 'slight_left'
# Image saved to slight_right\20250319_204252248180.png under category 'slight_right'
# Image saved to slight_left\20250319_204252248666.png under category 'slight_left'
# Image saved to slight_right\20250319_204252250171.png under category 'slight_right'
# Image saved to slight_left\20250319_204252250171.png under category 'slight_left'
# Image saved to slight_right\20250319_204252252241.png under category 'slight_right'
# Image saved to slight_left\20250319_204252252241.png under category 'slight_left'
# Image saved to slight_right\20250319_204252252241.png under category 'slight_right'
# Image saved to slight_left\20250319_204252256268.png under category 'slight_left'
# Image saved to slight_right\20250319_204252256268.png under category 'slight_right'
# Image saved to slight_left\20250319_204252256268.png under category 'slight_left'
# Image saved to slight_right\20250319_204252256268.png under category 'slight_right'
# Image saved to slight_left\20250319_204252260349.png under category 'slight_left'
# Image saved to slight_right\20250319_204252260349.png under category 'slight_right'
# Image saved to slight_left\20250319_204252260349.png under category 'slight_left'
# Image saved to slight_right\20250319_204252260349.png under category 'slight_right'
# Image saved to slight_left\20250319_204252264855.png under category 'slight_left'
# Image saved to slight_right\20250319_204252265855.png under category 'slight_right'
# Image saved to slight_left\20250319_204252266855.png under category 'slight_left'
# Image saved to slight_right\20250319_204252267856.png under category 'slight_right'
# Image saved to slight_left\20250319_204252268854.png under category 'slight_left'
# Image saved to slight_right\20250319_204252270359.png under category 'slight_right'
# Image saved to slight_left\20250319_204252271366.png under category 'slight_left'
# Image saved to slight_right\20250319_204252272373.png under category 'slight_right'
# Image saved to slight_left\20250319_204252273372.png under category 'slight_left'
# Image saved to slight_right\20250319_204252274373.png under category 'slight_right'
# Image saved to slight_left\20250319_204252275373.png under category 'slight_left'
# Image saved to slight_right\20250319_204252276374.png under category 'slight_right'
# Image saved to slight_left\20250319_204252278374.png under category 'slight_left'
# Image saved to slight_right\20250319_204252280294.png under category 'slight_right'
# Image saved to slight_left\20250319_204252281815.png under category 'slight_left'
# Image saved to slight_right\20250319_204252281815.png under category 'slight_right'
# Image saved to slight_left\20250319_204252281815.png under category 'slight_left'
# Image saved to slight_right\20250319_204252285674.png under category 'slight_right'
# Image saved to slight_left\20250319_204252287120.png under category 'slight_left'
# Image saved to slight_right\20250319_204252287627.png under category 'slight_right'
# Image saved to slight_left\20250319_204252288637.png under category 'slight_left'
# Image saved to slight_right\20250319_204252291149.png under category 'slight_right'
# Image saved to slight_left\20250319_204252292148.png under category 'slight_left'
# Image saved to slight_right\20250319_204252293409.png under category 'slight_right'
# Image saved to slight_left\20250319_204252294415.png under category 'slight_left'
# Image saved to slight_right\20250319_204252295414.png under category 'slight_right'
# Image saved to slight_left\20250319_204252296415.png under category 'slight_left'
# Image saved to slight_right\20250319_204252297415.png under category 'slight_right'
# Image saved to slight_left\20250319_204252298415.png under category 'slight_left'
# Image saved to center\20250319_204252300923.png under category 'center'
# Image saved to center\20250319_204252303148.png under category 'center'
# Image saved to slight_right\20250319_204252304150.png under category 'slight_right'
# Image saved to slight_left\20250319_204252305147.png under category 'slight_left'
# Image saved to slight_right\20250319_204252306148.png under category 'slight_right'
# Image saved to slight_left\20250319_204252307147.png under category 'slight_left'
# Image saved to slight_right\20250319_204252308147.png under category 'slight_right'
# Image saved to slight_left\20250319_204252309148.png under category 'slight_left'
# Image saved to right\20250319_204252311346.png under category 'right'
# Image saved to left\20250319_204252312350.png under category 'left'
# Image saved to slight_right\20250319_204252314313.png under category 'slight_right'
# Image saved to slight_left\20250319_204252314313.png under category 'slight_left'
# Image saved to slight_right\20250319_204252317129.png under category 'slight_right'
# Image saved to slight_left\20250319_204252317129.png under category 'slight_left'
# Image saved to slight_right\20250319_204252317129.png under category 'slight_right'
# Image saved to slight_left\20250319_204252320083.png under category 'slight_left'
# Image saved to slight_right\20250319_204252321112.png under category 'slight_right'
# Image saved to slight_left\20250319_204252321112.png under category 'slight_left'
# Image saved to slight_right\20250319_204252321112.png under category 'slight_right'
# Image saved to slight_left\20250319_204252325269.png under category 'slight_left'
# Image saved to slight_right\20250319_204252325269.png under category 'slight_right'
# Image saved to slight_left\20250319_204252325269.png under category 'slight_left'
# Image saved to slight_right\20250319_204252325269.png under category 'slight_right'
# Image saved to slight_left\20250319_204252325269.png under category 'slight_left'
# Image saved to center\20250319_204252330359.png under category 'center'
# Image saved to center\20250319_204252331520.png under category 'center'
# Image saved to center\20250319_204252333637.png under category 'center'
# Image saved to center\20250319_204252334637.png under category 'center'
# Image saved to center\20250319_204252335636.png under category 'center'
# Image saved to center\20250319_204252336637.png under category 'center'
# Image saved to center\20250319_204252337638.png under category 'center'
# Image saved to center\20250319_204252338637.png under category 'center'
# Image saved to slight_right\20250319_204252340142.png under category 'slight_right'
# Image saved to slight_left\20250319_204252342148.png under category 'slight_left'
# Image saved to slight_right\20250319_204252342148.png under category 'slight_right'
# Image saved to slight_left\20250319_204252343149.png under category 'slight_left'
# Image saved to slight_right\20250319_204252345149.png under category 'slight_right'
# Image saved to slight_left\20250319_204252346149.png under category 'slight_left'
# Image saved to slight_right\20250319_204252346149.png under category 'slight_right'
# Image saved to slight_left\20250319_204252347148.png under category 'slight_left'
# Image saved to slight_right\20250319_204252350290.png under category 'slight_right'
# Image saved to slight_left\20250319_204252351297.png under category 'slight_left'
# Image saved to slight_right\20250319_204252352296.png under category 'slight_right'
# Image saved to slight_left\20250319_204252353297.png under category 'slight_left'
# Image saved to slight_right\20250319_204252354297.png under category 'slight_right'
# Image saved to slight_left\20250319_204252355296.png under category 'slight_left'
# Image saved to slight_right\20250319_204252356297.png under category 'slight_right'
# Image saved to slight_left\20250319_204252357296.png under category 'slight_left'
# Image saved to slight_right\20250319_204252359298.png under category 'slight_right'
# Image saved to slight_left\20250319_204252360300.png under category 'slight_left'
# Image saved to slight_right\20250319_204252361355.png under category 'slight_right'
# Image saved to slight_left\20250319_204252362354.png under category 'slight_left'
# Image saved to slight_right\20250319_204252363355.png under category 'slight_right'
# Image saved to slight_left\20250319_204252364355.png under category 'slight_left'
# Image saved to slight_right\20250319_204252365355.png under category 'slight_right'
# Image saved to slight_left\20250319_204252365355.png under category 'slight_left'
# Image saved to slight_right\20250319_204252367803.png under category 'slight_right'
# Image saved to slight_left\20250319_204252369543.png under category 'slight_left'
# Image saved to slight_right\20250319_204252370049.png under category 'slight_right'
# Image saved to slight_left\20250319_204252370049.png under category 'slight_left'
# Image saved to slight_right\20250319_204252370049.png under category 'slight_right'
# Image saved to slight_left\20250319_204252372479.png under category 'slight_left'
# Image saved to slight_right\20250319_204252372479.png under category 'slight_right'
# Image saved to slight_left\20250319_204252373985.png under category 'slight_left'
# Image saved to slight_right\20250319_204252373985.png under category 'slight_right'
# Image saved to slight_left\20250319_204252373985.png under category 'slight_left'
# Image saved to slight_right\20250319_204252378209.png under category 'slight_right'
# Image saved to slight_left\20250319_204252378209.png under category 'slight_left'
# Image saved to slight_right\20250319_204252380214.png under category 'slight_right'
# Image saved to slight_left\20250319_204252380214.png under category 'slight_left'
# Image saved to slight_right\20250319_204252382205.png under category 'slight_right'
# Image saved to slight_left\20250319_204252382205.png under category 'slight_left'
# Image saved to right\20250319_204252385975.png under category 'right'
# Image saved to left\20250319_204252385975.png under category 'left'
# Image saved to right\20250319_204252385975.png under category 'right'
# Image saved to left\20250319_204252385975.png under category 'left'
# Image saved to slight_right\20250319_204252385975.png under category 'slight_right'
# Image saved to slight_left\20250319_204252390042.png under category 'slight_left'
# Image saved to slight_right\20250319_204252390042.png under category 'slight_right'
# Image saved to slight_left\20250319_204252390042.png under category 'slight_left'
# Image saved to right\20250319_204252393040.png under category 'right'
# Image saved to left\20250319_204252394547.png under category 'left'
# Image saved to right\20250319_204252394547.png under category 'right'
# Image saved to left\20250319_204252394547.png under category 'left'
# Image saved to right\20250319_204252398174.png under category 'right'
# Image saved to left\20250319_204252398621.png under category 'left'
# Image saved to right\20250319_204252400127.png under category 'right'
# Image saved to left\20250319_204252400127.png under category 'left'
# Image saved to right\20250319_204252402219.png under category 'right'
# Image saved to left\20250319_204252402219.png under category 'left'
# Image saved to right\20250319_204252402219.png under category 'right'
# Image saved to left\20250319_204252406286.png under category 'left'
# Image saved to right\20250319_204252406286.png under category 'right'
# Image saved to left\20250319_204252406286.png under category 'left'
# Image saved to slight_right\20250319_204252406286.png under category 'slight_right'
# Image saved to slight_left\20250319_204252406286.png under category 'slight_left'
# Image saved to slight_right\20250319_204252410215.png under category 'slight_right'
# Image saved to slight_left\20250319_204252410215.png under category 'slight_left'
# Image saved to slight_right\20250319_204252410215.png under category 'slight_right'
# Image saved to slight_left\20250319_204252414382.png under category 'slight_left'
# Image saved to slight_right\20250319_204252415842.png under category 'slight_right'
# Image saved to slight_left\20250319_204252416842.png under category 'slight_left'
# Image saved to slight_right\20250319_204252417842.png under category 'slight_right'
# Image saved to slight_left\20250319_204252418841.png under category 'slight_left'
# Image saved to slight_right\20250319_204252419995.png under category 'slight_right'
# Image saved to slight_left\20250319_204252419995.png under category 'slight_left'
# Image saved to slight_right\20250319_204252423150.png under category 'slight_right'
# Image saved to slight_left\20250319_204252423150.png under category 'slight_left'
# Image saved to slight_right\20250319_204252423150.png under category 'slight_right'
# ...
# Image saved to slight_left\20250319_204254173010.png under category 'slight_left'
# Image saved to slight_right\20250319_204254175009.png under category 'slight_right'
# Image saved to slight_left\20250319_204254175009.png under category 'slight_left'
# Image saved to slight_right\20250319_204254176505.png under category 'slight_right'
# Image saved to slight_left\20250319_204254177511.png under category 'slight_left'
# Image saved to slight_right\20250319_204254178510.png under category 'slight_right'
# Image saved to slight_left\20250319_204254180016.png under category 'slight_left'
# Image saved to slight_right\20250319_204254181023.png under category 'slight_right'
# Image saved to slight_left\20250319_204254182024.png under category 'slight_left'
# Image saved to slight_right\20250319_204254183351.png under category 'slight_right'
# Image saved to slight_left\20250319_204254183351.png under category 'slight_left'
# Image saved to slight_right\20250319_204254187073.png under category 'slight_right'
# Image saved to slight_left\20250319_204254187073.png under category 'slight_left'
# Image saved to slight_right\20250319_204254187073.png under category 'slight_right'
# Image saved to slight_left\20250319_204254190146.png under category 'slight_left'
# Image saved to slight_right\20250319_204254191167.png under category 'slight_right'
# Image saved to slight_left\20250319_204254191167.png under category 'slight_left'
# Image saved to slight_right\20250319_204254193175.png under category 'slight_right'
# Image saved to slight_left\20250319_204254193175.png under category 'slight_left'
# Image saved to slight_right\20250319_204254195182.png under category 'slight_right'
# Image saved to slight_left\20250319_204254195182.png under category 'slight_left'
# Image saved to slight_right\20250319_204254198131.png under category 'slight_right'
# Image saved to slight_left\20250319_204254199139.png under category 'slight_left'
# Image saved to slight_right\20250319_204254200138.png under category 'slight_right'
# Image saved to slight_left\20250319_204254201181.png under category 'slight_left'
# Image saved to right\20250319_204254203732.png under category 'right'
# Image saved to left\20250319_204254203732.png under category 'left'
# Image saved to slight_right\20250319_204254203732.png under category 'slight_right'
# Image saved to slight_left\20250319_204254203732.png under category 'slight_left'
# Image saved to slight_right\20250319_204254207749.png under category 'slight_right'
# Image saved to slight_left\20250319_204254207749.png under category 'slight_left'
# Image saved to slight_right\20250319_204254207749.png under category 'slight_right'
# Image saved to slight_left\20250319_204254210255.png under category 'slight_left'
# Image saved to right\20250319_204254211772.png under category 'right'
# Image saved to left\20250319_204254211772.png under category 'left'
# Image saved to right\20250319_204254214804.png under category 'right'
# Image saved to left\20250319_204254215812.png under category 'left'
# Image saved to right\20250319_204254216813.png under category 'right'
# Image saved to left\20250319_204254217812.png under category 'left'
# Image saved to slight_right\20250319_204254218812.png under category 'slight_right'
# Image saved to slight_left\20250319_204254218812.png under category 'slight_left'
# Image saved to right\20250319_204254221401.png under category 'right'
# Image saved to left\20250319_204254222413.png under category 'left'
# Image saved to right\20250319_204254224406.png under category 'right'
# Image saved to left\20250319_204254225407.png under category 'left'
# Image saved to right\20250319_204254226406.png under category 'right'
# Image saved to left\20250319_204254227407.png under category 'left'
# Image saved to right\20250319_204254228406.png under category 'right'
# Image saved to left\20250319_204254229407.png under category 'left'
# Image saved to right\20250319_204254231863.png under category 'right'
# Image saved to left\20250319_204254232889.png under category 'left'
# Image saved to right\20250319_204254233889.png under category 'right'
# Image saved to left\20250319_204254234890.png under category 'left'
# Image saved to right\20250319_204254235889.png under category 'right'
# Image saved to left\20250319_204254236889.png under category 'left'
# Image saved to slight_right\20250319_204254237889.png under category 'slight_right'
# Image saved to slight_left\20250319_204254238890.png under category 'slight_left'
# Image saved to slight_right\20250319_204254240396.png under category 'slight_right'
# Image saved to slight_left\20250319_204254241405.png under category 'slight_left'
# Image saved to slight_right\20250319_204254257917.png under category 'slight_right'
# Image saved to slight_left\20250319_204254258917.png under category 'slight_left'
# Image saved to slight_right\20250319_204254258917.png under category 'slight_right'
# Image saved to slight_left\20250319_204254261433.png under category 'slight_left'
# Image saved to slight_right\20250319_204254262439.png under category 'slight_right'
# Image saved to slight_left\20250319_204254263438.png under category 'slight_left'
# Image saved to slight_right\20250319_204254265439.png under category 'slight_right'
# Image saved to slight_left\20250319_204254265439.png under category 'slight_left'
# Image saved to slight_right\20250319_204254265439.png under category 'slight_right'
# Image saved to slight_left\20250319_204254265439.png under category 'slight_left'
# Image saved to slight_right\20250319_204254269530.png under category 'slight_right'
# Image saved to slight_left\20250319_204254270036.png under category 'slight_left'
# Image saved to slight_right\20250319_204254270036.png under category 'slight_right'
# Image saved to slight_left\20250319_204254270036.png under category 'slight_left'
# Image saved to slight_right\20250319_204254273698.png under category 'slight_right'
# Image saved to slight_left\20250319_204254273698.png under category 'slight_left'
# Image saved to slight_right\20250319_204254273698.png under category 'slight_right'
# Image saved to slight_left\20250319_204254273698.png under category 'slight_left'
# Image saved to slight_right\20250319_204254273698.png under category 'slight_right'
# Image saved to slight_left\20250319_204254278022.png under category 'slight_left'
# Image saved to slight_right\20250319_204254278022.png under category 'slight_right'
# Image saved to slight_left\20250319_204254278022.png under category 'slight_left'
# Image saved to slight_right\20250319_204254280029.png under category 'slight_right'
# Image saved to slight_left\20250319_204254281946.png under category 'slight_left'
# Image saved to slight_right\20250319_204254281946.png under category 'slight_right'
# Image saved to slight_left\20250319_204254281946.png under category 'slight_left'
# Image saved to slight_right\20250319_204254281946.png under category 'slight_right'
# Image saved to slight_left\20250319_204254285694.png under category 'slight_left'
# Image saved to slight_right\20250319_204254285694.png under category 'slight_right'
# Image saved to slight_left\20250319_204254285694.png under category 'slight_left'
# Image saved to center\20250319_204254285694.png under category 'center'
# Image saved to center\20250319_204254290010.png under category 'center'
# Image saved to center\20250319_204254290010.png under category 'center'
# Image saved to center\20250319_204254290010.png under category 'center'
# Image saved to center\20250319_204254290010.png under category 'center'
# Image saved to center\20250319_204254290010.png under category 'center'
# Image saved to right\20250319_204254294141.png under category 'right'
# Image saved to left\20250319_204254294141.png under category 'left'
# Image saved to center\20250319_204254294141.png under category 'center'
# Image saved to center\20250319_204254294141.png under category 'center'
# Image saved to center\20250319_204254298151.png under category 'center'
# Image saved to center\20250319_204254299159.png under category 'center'
# Image saved to center\20250319_204254300158.png under category 'center'
# Image saved to center\20250319_204254301432.png under category 'center'
# Image saved to center\20250319_204254301432.png under category 'center'
# Image saved to center\20250319_204254301432.png under category 'center'
# Image saved to center\20250319_204254304190.png under category 'center'
# Image saved to center\20250319_204254304190.png under category 'center'
# Image saved to center\20250319_204254304190.png under category 'center'
# Image saved to center\20250319_204254304190.png under category 'center'
# Image saved to center\20250319_204254308493.png under category 'center'
# Image saved to center\20250319_204254308493.png under category 'center'
# Image saved to center\20250319_204254309999.png under category 'center'
# Image saved to center\20250319_204254309999.png under category 'center'
# Image saved to slight_right\20250319_204254312020.png under category 'slight_right'
# Image saved to slight_left\20250319_204254312020.png under category 'slight_left'
# Image saved to slight_right\20250319_204254312020.png under category 'slight_right'
# Image saved to slight_left\20250319_204254315279.png under category 'slight_left'
# Image saved to slight_right\20250319_204254315279.png under category 'slight_right'
# Image saved to slight_left\20250319_204254315279.png under category 'slight_left'
# Image saved to slight_right\20250319_204254315279.png under category 'slight_right'
# Image saved to slight_left\20250319_204254319024.png under category 'slight_left'
# Image saved to slight_right\20250319_204254320032.png under category 'slight_right'
# Image saved to slight_left\20250319_204254320032.png under category 'slight_left'
# Image saved to slight_right\20250319_204254320032.png under category 'slight_right'
# Image saved to slight_left\20250319_204254320032.png under category 'slight_left'
# Image saved to slight_right\20250319_204254323447.png under category 'slight_right'
# Image saved to slight_left\20250319_204254323447.png under category 'slight_left'
# Image saved to slight_right\20250319_204254323447.png under category 'slight_right'
# Image saved to slight_left\20250319_204254323447.png under category 'slight_left'
# Image saved to slight_right\20250319_204254327883.png under category 'slight_right'
# Image saved to slight_left\20250319_204254327883.png under category 'slight_left'
# Image saved to slight_right\20250319_204254327883.png under category 'slight_right'
# Image saved to slight_left\20250319_204254330389.png under category 'slight_left'
# Image saved to slight_right\20250319_204254331486.png under category 'slight_right'
# Image saved to slight_left\20250319_204254331940.png under category 'slight_left'
# Image saved to slight_right\20250319_204254331940.png under category 'slight_right'
# Image saved to slight_left\20250319_204254331940.png under category 'slight_left'
# Image saved to slight_right\20250319_204254335950.png under category 'slight_right'
# Image saved to slight_left\20250319_204254335950.png under category 'slight_left'
# Image saved to slight_right\20250319_204254335950.png under category 'slight_right'
# Image saved to slight_left\20250319_204254335950.png under category 'slight_left'
# Image saved to slight_right\20250319_204254335950.png under category 'slight_right'
# Image saved to slight_left\20250319_204254340099.png under category 'slight_left'
# Image saved to slight_right\20250319_204254340099.png under category 'slight_right'
# Image saved to slight_left\20250319_204254340099.png under category 'slight_left'
# Image saved to slight_right\20250319_204254340099.png under category 'slight_right'
# Image saved to slight_left\20250319_204254344224.png under category 'slight_left'
# Image saved to slight_right\20250319_204254344224.png under category 'slight_right'
# Image saved to slight_left\20250319_204254344224.png under category 'slight_left'
# Image saved to slight_right\20250319_204254344224.png under category 'slight_right'
# Image saved to slight_left\20250319_204254344224.png under category 'slight_left'
# Image saved to slight_right\20250319_204254348149.png under category 'slight_right'
# Image saved to slight_left\20250319_204254349156.png under category 'slight_left'
# Image saved to slight_right\20250319_204254350154.png under category 'slight_right'
# Image saved to slight_left\20250319_204254350154.png under category 'slight_left'
# Image saved to slight_right\20250319_204254350154.png under category 'slight_right'
# Image saved to slight_left\20250319_204254350154.png under category 'slight_left'
# Image saved to slight_right\20250319_204254354541.png under category 'slight_right'
# Image saved to slight_left\20250319_204254355717.png under category 'slight_left'
# Image saved to slight_right\20250319_204254355717.png under category 'slight_right'
# Image saved to slight_left\20250319_204254356717.png under category 'slight_left'
# Image saved to right\20250319_204254358714.png under category 'right'
# Image saved to left\20250319_204254358714.png under category 'left'
# Image saved to right\20250319_204254361224.png under category 'right'
# Image saved to left\20250319_204254361224.png under category 'left'
# Image saved to right\20250319_204254362224.png under category 'right'
# Image saved to left\20250319_204254363224.png under category 'left'
# Image saved to slight_right\20250319_204254364224.png under category 'slight_right'
# Image saved to slight_left\20250319_204254365225.png under category 'slight_left'
# Image saved to slight_right\20250319_204254366705.png under category 'slight_right'
# Image saved to slight_left\20250319_204254367711.png under category 'slight_left'
# Image saved to slight_right\20250319_204254368711.png under category 'slight_right'
# Image saved to slight_left\20250319_204254370215.png under category 'slight_left'
# Image saved to slight_right\20250319_204254371221.png under category 'slight_right'
# Image saved to slight_left\20250319_204254372221.png under category 'slight_left'
# Image saved to slight_right\20250319_204254373227.png under category 'slight_right'
# Image saved to slight_left\20250319_204254374227.png under category 'slight_left'
# Image saved to slight_right\20250319_204254375226.png under category 'slight_right'
# Image saved to slight_left\20250319_204254376228.png under category 'slight_left'
# Image saved to slight_right\20250319_204254377226.png under category 'slight_right'
# Image saved to slight_left\20250319_204254378227.png under category 'slight_left'
# Image saved to right\20250319_204254379227.png under category 'right'
# Image saved to left\20250319_204254379227.png under category 'left'
# Image saved to slight_right\20250319_204254380228.png under category 'slight_right'
# Image saved to slight_left\20250319_204254381257.png under category 'slight_left'
# Image saved to slight_right\20250319_204254382141.png under category 'slight_right'
# Image saved to slight_left\20250319_204254382141.png under category 'slight_left'
# Image saved to slight_right\20250319_204254382141.png under category 'slight_right'
# Image saved to slight_left\20250319_204254385593.png under category 'slight_left'
# Image saved to right\20250319_204254385593.png under category 'right'
# Image saved to left\20250319_204254385593.png under category 'left'
# Image saved to slight_right\20250319_204254385593.png under category 'slight_right'
# Image saved to slight_left\20250319_204254390183.png under category 'slight_left'
# Image saved to slight_right\20250319_204254390183.png under category 'slight_right'
# Image saved to slight_left\20250319_204254390183.png under category 'slight_left'
# Image saved to slight_right\20250319_204254390183.png under category 'slight_right'
# Image saved to slight_left\20250319_204254390183.png under category 'slight_left'
# Image saved to right\20250319_204254394425.png under category 'right'
# Image saved to left\20250319_204254394425.png under category 'left'
# Image saved to slight_right\20250319_204254394425.png under category 'slight_right'
# Image saved to slight_left\20250319_204254394425.png under category 'slight_left'

# %%
import os
import shutil
import random

def move_images(train_dir: str, valid_dir: str, num_images: int = 100):
    categories = ['left', 'slight_left', 'center', 'slight_right', 'right','crossing']
    for category in categories:
        train_category_path = os.path.join(train_dir, category)
        valid_category_path = os.path.join(valid_dir, category)
        os.makedirs(valid_category_path, exist_ok=True)

        # List all images in the category folder
        images = [f for f in os.listdir(train_category_path) if os.path.isfile(os.path.join(train_category_path, f))]

        # Randomly select images
        selected_images = random.sample(images, min(num_images, len(images)))

        for image in selected_images:
            src_path = os.path.join(train_category_path, image)
            dest_path = os.path.join(valid_category_path, image)

            # Move image to validation folder
            shutil.move(src_path, dest_path)

        print(f"Moved {len(selected_images)} images from {train_category_path} to {valid_category_path}")


# Example usage
#move_images('dataset/train', 'dataset/valid')
# Out:
# Moved 100 images from dataset/train\crossing to dataset/valid\crossing

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class LineFollower(nn.Module):
    def __init__(self, num_classes):  
        super(LineFollower, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=5, padding=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=50, kernel_size=5, padding=2)
        self.conv3 = nn.Conv2d(in_channels=50, out_channels=30, kernel_size=3, padding=1)
        
        # Pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.pool2 = nn.MaxPool2d(kernel_size=5, stride=5)
        
        # Fully connected layers
        self.fc1 = nn.Linear(30 * 5 * 32, 128)  # Assuming input size is (50, 320)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        # Convolutional layers with ReLU and pooling
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = F.relu(self.conv3(x))
        
        # Flatten the output
        x = x.view(x.size(0), -1)
        
        # Fully connected layers with ReLU
        x = F.relu(self.fc1(x))
        
        # Output layer
        x = self.fc2(x)
        
        return x
    
# Create a model
model = LineFollower(num_classes=6) 
print(model)
# Out:
# LineFollower(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(50, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (pool2): MaxPool2d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=4800, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=6, bias=True)
# )

# %%
# LOAD DATA

import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Define directories for train and validation
train_dir = "dataset/train"
valid_dir = "dataset/valid"

# Define image transformations
transform = transforms.Compose([
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    transforms.Grayscale(),
    #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize for pre-trained models
])

# Load datasets
train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
valid_dataset = datasets.ImageFolder(root=valid_dir, transform=transform)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=True)

# Check the labels
print("Classes:", train_dataset.classes)
print("Number of training samples:", len(train_dataset))
print("Number of validation samples:", len(valid_dataset))

# Checking a batch of images
images, labels = next(iter(train_loader))
print("Image batch shape:", images.shape)
print("Labels batch shape:", labels.shape)
# Out:
# Classes: ['center', 'crossing', 'left', 'right', 'slight_left', 'slight_right']
# Number of training samples: 32267
# Number of validation samples: 600
# Image batch shape: torch.Size([32, 1, 50, 320])
# Labels batch shape: torch.Size([32])

# %%
# TRAINING 
import torch.optim as optim
import torch.nn as nn
from tqdm import tqdm

# Select the available device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Hyperparameters
learning_rate = 0.001
num_epochs = 1

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training loop
for epoch in tqdm(range(num_epochs)):
    model.train()
    running_loss = 0.0

    for images, labels in train_loader:
        # Move data to GPU if available
        images, labels = images.to(device), labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch [{epoch}/{num_epochs}]: loss = {loss.item()}")
# Out:
# 100%|██████████| 1/1 [05:05<00:00, 305.29s/it]
# Epoch [0/1]: loss = 0.003938284236937761

# %%
# Accuracy on the test set
correct = 0
total = len(valid_dataset)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
with torch.no_grad():
    # Iterate through test set minibatchs 
    for images, labels in tqdm(valid_loader):
        images, labels = images.to(device), labels.to(device)
        # Forward pass
        x = images  
        y = model(x)

        predictions = torch.argmax(y, dim=1)
        correct += torch.sum((predictions == labels).float())

accuracy = correct/total
print('Test accuracy: {}'.format(accuracy))
# Out:
# 100%|██████████| 19/19 [00:01<00:00, 13.56it/s]
# Test accuracy: 0.9883333444595337

# %%
# Compare and save the best model

import os
import torch
import re

def save_best_model(model, new_accuracy, directory=".", model_name="best_model"):
    """
    Saves the model if its accuracy is higher than the previous best one.
    
    Args:
        model (torch.nn.Module): The PyTorch model to save.
        new_accuracy (float): The new model's accuracy to compare.
        directory (str): Directory where the model files are saved.
        model_name (str): Base name of the model file.
        
    Returns:
        bool: True if the new model was saved, False otherwise.
    """
    best_accuracy = 0.0
    best_model_file = None

    # Look for the best model file in the directory
    for filename in os.listdir(directory):
        match = re.match(rf"{model_name}_(\d+.\d+).pt", filename)
        if match:
            saved_accuracy = float(match.group(1))
            if saved_accuracy > best_accuracy:
                best_accuracy = saved_accuracy
                best_model_file = filename

    # Compare accuracies
    if new_accuracy > best_accuracy:
        # Save new model
        new_model_file = f"{model_name}_{new_accuracy:.2f}.pt"
        torch.save(model.state_dict(), os.path.join(directory, new_model_file))
        print(f"New best model saved: {new_model_file} (Accuracy: {new_accuracy:.2f}%)")
        return True
    else:
        print(f"No improvement. Current best model: {best_model_file} (Accuracy: {best_accuracy:.2f}%)")
        return False
    
save_best_model(model, accuracy)
# Out:
# No improvement. Current best model: best_model_0.99.pt (Accuracy: 0.99%)
# False

# %%
# TEST MODEL ON A SINGLE IMAGE

from PIL import Image
from CNNmodel import LineFollower
import torch
import cv2
from torchvision import transforms

transform = transforms.Compose([
        transforms.ToTensor(),           # Convert images to PyTorch tensors
        transforms.Grayscale(),
    ])

model = LineFollower(num_classes=6)
model.load_state_dict(torch.load('best_model_0.99.pt'))
categories = ['center', 'crossing', 'left', 'right', 'slight_left', 'slight_right']

image = cv2.imread("test_img.png")
# Apply the transform
pil_image = Image.fromarray(image)
img = transform(pil_image)

# Now you can pass it to the model
prob = model(img.unsqueeze(0))  # Add a batch dimension if the model expects it
print(prob)
predictions = torch.argmax(prob, dim=1)
predictions
# Out:
# tensor([[-3.3527,  0.5508, -7.6807, -3.6213, -5.5003, -1.4040]],
#        grad_fn=<AddmmBackward0>)
# tensor([1])
